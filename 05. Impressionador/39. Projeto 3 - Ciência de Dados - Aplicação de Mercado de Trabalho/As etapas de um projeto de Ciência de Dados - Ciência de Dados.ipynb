# %% [markdown]
# # Ciência de Dados
#
# ### O que é?
#
# - � voc� usar os dados/informa��es do neg�cio para extrair informa��es valiosas e ajudar na tomada de decis�o.
# - De forma simples e o que � usado em muitas empresas -> � voc� resolver um desafio da empresa/do neg�cio usando os dados dispon�veis
# - O certo seria: Ci�ncia de Dados t� preocupado em resolver os desafios do neg�cio e saber o que fazer no futuro, fazer alguma previs�o que vai ajudar a tomar o rumo da empresa e o Business Intelligence t� em descrever como as coisas funcionaram/funcionaram at� aqui
#
# ### Diferen�a de Ci�ncia de Dados e Machine Learning
#
# - Machine Learning faz parte da Ci�ncia de Dados, � um modelo dispon�vel para ajudar a prever alguma coisa.
#
# ### Onde podemos aplicar Ci�ncia de Dados
#
# - Em qualquer empresa basicamente, afinal, todas as empresas tem dados dispon�veis.
# - Mas na pr�tica, podemos aplicar em todo lugar porque o objetivo � resolver um desafio do neg�cio usando dados. Ent�o em qualquer empresa que voc� consiga usar os dados dispon�veis para resolver um desafio da empresa, voc� pode aplicar Ci�ncia de Dados
#
# ### Como funciona um Projeto de Ci�ncia de Dados na pr�tica
#
# S�o v�rias etapas importantes, de forma bem completa:
#
# 1. Entendimento do Desafio que voc� quer resolver
# 2. Entendimento da Empresa/�rea
# 3. Extra��o/Obten��o de Dados
# 4. Ajustes de Dados (Limpeza de Dados)
# 5. An�lise Explorat�ria
# 6. Modelagem + Algoritmos
# 7. Interpreta��o dos Resultados
# 8. Deploy/Produ��o
#
# ### Onde o Python entra no meio disso tudo?
#
# O Python � a ferramenta que vai te permitir fazer isso tudo, desde o 3 at� o 8
#
# ### Mostrando um Projeto de Ci�ncia de Dados Completo na Pr�tica
#
# - Recomenda��o -> Kaggle
# - Vamos ver como funciona na pr�tica (n�o tente entender o c�digo, tente entender os passos)
#
# ### O que vamos ter no Programa Python Impressionador de Ci�ncia de Dados
#
# - 1 Projeto Completo, do 1 ao 8 em Ci�ncia de Dados
# - Outros m�dulos que v�o te ajudar em v�rias outras etapas espec�ficas (Ex: integra��o Python com SQL para o Ponto 3)
