# %%
#%pip install selenium
#º%pip install pandas
#%pip install openpyxl

# %% [markdown]
# ### Passo a Passo do projeto

# %%
# Passo a passo
# Passo 1: Abrir o navegador
# Passo 2: Carregar a lista de produtos (livros)
# Passo 3: Para cada item da lista (para cada livro)
    # Passo 4: Pesquisar no gutenberg: https://www.gutenberg.org/
    # Passo 5: Se não encontrar:
        # Pesquisar no https://books.toscrape.com/
    # Passo 6: Registrar preço e link do livro na planilha

# %% [markdown]
# ### Automação

# %%
# abrindo navegador
from selenium import webdriver

#criar navegador
navegador = webdriver.Chrome()

# %%
# importando planilha
import pandas as pd

df_produtos = pd.read_excel('Produtos.xlsx')
display(df_produtos)
# Out:
#                     nome            autor   categoria  preco  link
# 0           Frankenstein     Mary Shelley    Classics    NaN   NaN
# 1       Romeo and Juliet      Shakespeare    Classics    NaN   NaN
# 2       The Great Gatsby       Fitzgerald    Classics    NaN   NaN
# 3  Algorithms to Live By  Brian Christian  Nonfiction    NaN   NaN
# 4                Sapiens     Yuval Harari     History    NaN   NaN
# 5  Smarter Faster Better   Charles Duhigg  Nonfiction    NaN   NaN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# Passo a passo
# Passo 1: Abrir o navegador
navegador = webdriver.Chrome()
# Passo 2: Carregar a lista de produtos (livros)
# Passo 3: Para cada item da lista (para cada livro)
# Passo 4: Pesquisar no gutenberg: https://www.gutenberg.org/

nome = "Frankenstein"
autor = "Mary Shalley"
categoria = "Classics"

def pesquisar_gutenberg(nome, autor, navegador):
    lista_palavras_autor = autor.split(" ")
    navegador.get("https://www.gutenberg.org/") 
    # selecionar 1 elemento no selenium
    # id -> identificador unico
    # class -> costuma identificar elementos parecidos (usada no CSS)
    # texto -> pelo texto contido no elemento
    # xpath -> muito específico

    # para listas de elementos:
    # class 
    # tag name

    elemento = navegador.find_element("class name", "search-input")
    elemento.send_keys(nome)
    elemento.send_keys(Keys.ENTER)

    lista_resultados = navegador.find_elements("class name", "booklink")
    link = None
    for resultado in lista_resultados:
        texto = resultado.text
        if nome.lower() in texto.lower():
            if all(palavra in texto for palavra in lista_palavras_autor):  
                link = resultado.find_element("class name", "link").get_attribute("href")
                break
    if link:
        preco = 0
    else:
        preco = None
    return link, preco

link, preco = pesquisar_gutenberg(nome, autor, navegador)
print(link, preco)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[2], line 46
#      43         preco = None
#      44     return link, preco
# ---> 46 link, preco = pesquisar_gutenberg(nome, autor, navegador)
#      47 print(link, preco)
#
# Cell In[2], line 28, in pesquisar_gutenberg(nome, autor, navegador)
#      17 navegador.get("https://www.gutenberg.org/")
#      18 # selecionar 1 elemento no selenium
#      19 # id -> identificador unico
#      20 # class -> costuma identificar elementos parecidos (usada no CSS)
#    (...)     25 # class
#      26 # tag name
# ---> 28 elemento = navegador.find_element("class name", "search-input")
#      29 elemento.send_keys(nome)
#      30 elemento.send_keys(Keys.ENTER)
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=150.0.7871.116)
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff703d7a865+152a5]
# 	chromedriver!GetHandleVerifier [0x7ff703d7a8c0+15300]
# 	chromedriver!(No symbol) [0x7ff7038d596d]
# 	chromedriver!(No symbol) [0x7ff7038ac782]
# 	chromedriver!(No symbol) [0x7ff7039601d6]
# 	chromedriver!(No symbol) [0x7ff70397d5b2]
# 	chromedriver!(No symbol) [0x7ff703922b3c]
# 	chromedriver!(No symbol) [0x7ff703923a53]
# 	chromedriver!GetHandleVerifier [0x7ff70435d3a1+5f7de1]
# 	chromedriver!GetHandleVerifier [0x7ff704357a3b+5f247b]
# 	chromedriver!GetHandleVerifier [0x7ff70437bca5+6166e5]
# 	chromedriver!GetHandleVerifier [0x7ff703d972ae+31cee]
# 	chromedriver!GetHandleVerifier [0x7ff703d9fe3c+3a87c]
# 	chromedriver!GetHandleVerifier [0x7ff703d84404+1ee44]
# 	chromedriver!GetHandleVerifier [0x7ff703d84594+1efd4]
# 	chromedriver!GetHandleVerifier [0x7ff703d675c7+2007]
# 	KERNEL32!BaseThreadInitThunk [0x7ff9c4b97374+14]
# 	ntdll!RtlUserThreadStart [0x7ff9c5e7cc91+21]

# %%
nome = "Sapiens"
autor = "Yuval Harari"
categoria = "History"

def pesquisar_bookstocrape(nome, autor, navegador):
    navegador = webdriver.Chrome()
    navegador.get("https://books.toscrape.com/") 
    lista_categorias = navegador.find_element("class name", "nav-list")
    try:
        lista_categorias.find_element("link text", categoria).click()
    except:
        print("Nenhuma categoria selecionada")

    lista_resultados = navegador.find_elements("class name", "product_pod")
    link = None
    # olhar todos os resultados da página
    for resultado in lista_resultados:
        elemento_h3 = resultado.find_element("tag name", "h3")
        elemento_do_link = elemento_h3.find_element("tag name", "a")
        titulo = elemento_do_link.get_attribute("title")
        if nome.lower() in titulo.lower():
                    link = elemento_do_link.get_attribute("href")
                    preco = resultado.find_element("class name", "price_color").text
                    break
    return link, preco

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

navegador = webdriver.Chrome()

df_produtos = pd.read_excel("Produtos.xlsx")
print(df_produtos)
# Out:
#                     nome            autor   categoria  preco  link
# 0           Frankenstein     Mary Shelley    Classics    NaN   NaN
# 1       Romeo and Juliet      Shakespeare    Classics    NaN   NaN
# 2       The Great Gatsby       Fitzgerald    Classics    NaN   NaN
# 3  Algorithms to Live By  Brian Christian  Nonfiction    NaN   NaN
# 4                Sapiens     Yuval Harari     History    NaN   NaN
# 5  Smarter Faster Better   Charles Duhigg  Nonfiction    NaN   NaN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

navegador = webdriver.Chrome()

df_produtos = pd.read_excel("Produtos.xlsx")
print(df_produtos)

def pesquisar_gutenberg(nome, autor, navegador):
    lista_palavras_autor = autor.split(" ")
    navegador.get("https://www.gutenberg.org/") 

    elemento = navegador.find_element("class name", "search-input")
    elemento.send_keys(nome)
    elemento.send_keys(Keys.ENTER)

    lista_resultados = navegador.find_elements("class name", "booklink")
    link = None
    for resultado in lista_resultados:
        texto = resultado.text
        if nome.lower() in texto.lower():
            if all(palavra in texto for palavra in lista_palavras_autor):  
                link = resultado.find_element("class name", "link").get_attribute("href")
                break
    if link:
        preco = 0
    else:
        preco = None
    return link, preco

def pesquisar_bookstocrape(nome, autor, navegador):
    navegador.get("https://books.toscrape.com/") 
    lista_categorias = navegador.find_element("class name", "nav-list")
    try:
        lista_categorias.find_element("link text", categoria).click()
    except:
        print("Nenhuma categoria selecionada")

    
    link = None
    preco = None
    encontrado = False
    while not encontrado: # passar entre as páginas da categoria
        lista_resultados = navegador.find_elements("class name", "product_pod")
        # olhar todos os resultados da página
        for resultado in lista_resultados:
            elemento_h3 = resultado.find_element("tag name", "h3")
            elemento_do_link = elemento_h3.find_element("tag name", "a")
            titulo = elemento_do_link.get_attribute("title")
            if nome.lower() in titulo.lower():
                encontrado = True
                # verificar se o autor é esse mesmo
                link = elemento_do_link.get_attribute("href")
                preco = resultado.find_element("class name", "price_color").text
                break
        # passar pra proxima página
        # tentar clicar no botão next
        try:
            navegador.find_element("link text", "next").click()
        # se não existir, eu vou interromper o while
        except:
            break
    return link, preco


for linha in df_produtos.index:
    nome = df_produtos.loc[linha, "nome"]
    autor = df_produtos.loc[linha, "autor"]
    categoria = df_produtos.loc[linha, "categoria"]

    link1, preco1 = pesquisar_gutenberg(nome, autor, navegador)
    print(nome, link1, preco1)
    if not link1:
        link2, preco2 = pesquisar_bookstocrape(nome, autor, navegador)
        print(nome, link2, preco2)
        df_produtos.loc[linha, "preco"] = preco2
        df_produtos.loc[linha, "link"] = link2
    else:
        df_produtos.loc[linha, "preco"] = preco1
        df_produtos.loc[linha, "link"] = link1

df_produtos.to_excel("ProdutosAtualizado.xlsx", index=False)
navegador.quit()
# Out:
#                     nome            autor   categoria  preco  link
# 0           Frankenstein     Mary Shelley    Classics    NaN   NaN
# 1       Romeo and Juliet      Shakespeare    Classics    NaN   NaN
# 2       The Great Gatsby       Fitzgerald    Classics    NaN   NaN
# 3  Algorithms to Live By  Brian Christian  Nonfiction    NaN   NaN
# 4                Sapiens     Yuval Harari     History    NaN   NaN
# 5  Smarter Faster Better   Charles Duhigg  Nonfiction    NaN   NaN
# Frankenstein None None
# Frankenstein None None
# Romeo and Juliet https://www.gutenberg.org/ebooks/1513 0
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_12004\2498455047.py:81: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://www.gutenberg.org/ebooks/1513' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_produtos.loc[linha, "link"] = link1
# The Great Gatsby https://www.gutenberg.org/ebooks/64317 0
# Algorithms to Live By None None
# Algorithms to Live By https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html £30.81
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_12004\2498455047.py:77: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '£30.81' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_produtos.loc[linha, "preco"] = preco2
# Sapiens None None
# Sapiens https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html £54.23
# Smarter Faster Better None None
# Smarter Faster Better https://books.toscrape.com/catalogue/smarter-faster-better-the-secrets-of-being-productive-in-life-and-business_543/index.html £38.89
