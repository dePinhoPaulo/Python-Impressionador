# %%
#!pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from python-docx) (6.0.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Criando Documento docx

# %%
from docx import Document

#criando documento
documento = Document()

faturmaento = 1000

texto = f"""Paulo
Bom dia!

O faturamento da empresa ontem foi de R${faturmaento}

Att."""

paragrafo = documento.add_paragraph(texto)

# %% [markdown]
# ### Formatando Paragrafo

# %%
from docx.shared import Pt, RGBColor, Cm #Valores de formatação
from docx.enum.style import WD_STYLE_TYPE 

paragrafo.style = documento.styles.add_style("EstiloPaulo", WD_STYLE_TYPE.PARAGRAPH)
paragrafo.style.font.name = 'Algerian'
paragrafo.style.font.size = Pt(15)
paragrafo.style.font.bold = True
paragrafo.style.font.italic = True

# %%
paragrafo_2 = documento.add_paragraph("Quantidade de produtos vendidos: 10", "EstiloPaulo")

# %% [markdown]
# ### Salvando arquivo

# %%
#salvando tados alterações no domento Texto.docx
documento.save('Texto.docx')

# %% [markdown]
# ### Estilos padrões do Word

# %%
for estilo in documento.styles:
    print(estilo)
# Out:
# _ParagraphStyle('Normal') id: 1791352185888
# _ParagraphStyle('Header') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('Footer') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('Heading 1') id: 1791351901792
# _ParagraphStyle('Heading 2') id: 1791352185888
# _ParagraphStyle('Heading 3') id: 1791351901792
# _ParagraphStyle('Heading 4') id: 1791352185888
# _ParagraphStyle('Heading 5') id: 1791351901792
# _ParagraphStyle('Heading 6') id: 1791352185888
# _ParagraphStyle('Heading 7') id: 1791351901792
# _ParagraphStyle('Heading 8') id: 1791352185888
# _ParagraphStyle('Heading 9') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _TableStyle('Normal Table') id: 1791351901792
# <docx.styles.style._NumberingStyle object at 0x000001A114E92420>
# _ParagraphStyle('No Spacing') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('Title') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('Subtitle') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('List Paragraph') id: 1791351901792
# _ParagraphStyle('Body Text') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('Body Text 2') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('Body Text 3') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('List') id: 1791352185888
# _ParagraphStyle('List 2') id: 1791351901792
# _ParagraphStyle('List 3') id: 1791352185888
# _ParagraphStyle('List Bullet') id: 1791351901792
# _ParagraphStyle('List Bullet 2') id: 1791352185888
# _ParagraphStyle('List Bullet 3') id: 1791351901792
# _ParagraphStyle('List Number') id: 1791352185888
# _ParagraphStyle('List Number 2') id: 1791351901792
# _ParagraphStyle('List Number 3') id: 1791352185888
# _ParagraphStyle('List Continue') id: 1791351901792
# _ParagraphStyle('List Continue 2') id: 1791352185888
# _ParagraphStyle('List Continue 3') id: 1791351901792
# _ParagraphStyle('macro') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('Quote') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('Caption') id: 1791352185888
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# _ParagraphStyle('Intense Quote') id: 1791351901792
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# <docx.styles.style.CharacterStyle object at 0x000001A114E92420>
# <docx.styles.style.CharacterStyle object at 0x000001A114E4CE60>
# _ParagraphStyle('TOC Heading') id: 1791352185888
# _TableStyle('Table Grid') id: 1791351901792
# _TableStyle('Light Shading') id: 1791352185888
# _TableStyle('Light Shading Accent 1') id: 1791351901792
# _TableStyle('Light Shading Accent 2') id: 1791352185888
# _TableStyle('Light Shading Accent 3') id: 1791351901792
# _TableStyle('Light Shading Accent 4') id: 1791352185888
# _TableStyle('Light Shading Accent 5') id: 1791351901792
# _TableStyle('Light Shading Accent 6') id: 1791352185888
# _TableStyle('Light List') id: 1791351901792
# _TableStyle('Light List Accent 1') id: 1791352185888
# _TableStyle('Light List Accent 2') id: 1791351901792
# _TableStyle('Light List Accent 3') id: 1791352185888
# _TableStyle('Light List Accent 4') id: 1791351901792
# _TableStyle('Light List Accent 5') id: 1791352185888
# _TableStyle('Light List Accent 6') id: 1791351901792
# _TableStyle('Light Grid') id: 1791352185888
# _TableStyle('Light Grid Accent 1') id: 1791351901792
# _TableStyle('Light Grid Accent 2') id: 1791352185888
# _TableStyle('Light Grid Accent 3') id: 1791351901792
# _TableStyle('Light Grid Accent 4') id: 1791352185888
# _TableStyle('Light Grid Accent 5') id: 1791351901792
# _TableStyle('Light Grid Accent 6') id: 1791352185888
# _TableStyle('Medium Shading 1') id: 1791351901792
# _TableStyle('Medium Shading 1 Accent 1') id: 1791352185888
# _TableStyle('Medium Shading 1 Accent 2') id: 1791351901792
# _TableStyle('Medium Shading 1 Accent 3') id: 1791352185888
# _TableStyle('Medium Shading 1 Accent 4') id: 1791351901792
# _TableStyle('Medium Shading 1 Accent 5') id: 1791352185888
# _TableStyle('Medium Shading 1 Accent 6') id: 1791351901792
# _TableStyle('Medium Shading 2') id: 1791352185888
# _TableStyle('Medium Shading 2 Accent 1') id: 1791351901792
# _TableStyle('Medium Shading 2 Accent 2') id: 1791352185888
# _TableStyle('Medium Shading 2 Accent 3') id: 1791351901792
# _TableStyle('Medium Shading 2 Accent 4') id: 1791352185888
# _TableStyle('Medium Shading 2 Accent 5') id: 1791351901792
# _TableStyle('Medium Shading 2 Accent 6') id: 1791352185888
# _TableStyle('Medium List 1') id: 1791351901792
# _TableStyle('Medium List 1 Accent 1') id: 1791352185888
# _TableStyle('Medium List 1 Accent 2') id: 1791351901792
# _TableStyle('Medium List 1 Accent 3') id: 1791352185888
# _TableStyle('Medium List 1 Accent 4') id: 1791351901792
# _TableStyle('Medium List 1 Accent 5') id: 1791352185888
# _TableStyle('Medium List 1 Accent 6') id: 1791351901792
# _TableStyle('Medium List 2') id: 1791352185888
# _TableStyle('Medium List 2 Accent 1') id: 1791351901792
# _TableStyle('Medium List 2 Accent 2') id: 1791352185888
# _TableStyle('Medium List 2 Accent 3') id: 1791351901792
# _TableStyle('Medium List 2 Accent 4') id: 1791352185888
# _TableStyle('Medium List 2 Accent 5') id: 1791351901792
# _TableStyle('Medium List 2 Accent 6') id: 1791352185888
# _TableStyle('Medium Grid 1') id: 1791351901792
# _TableStyle('Medium Grid 1 Accent 1') id: 1791352185888
# _TableStyle('Medium Grid 1 Accent 2') id: 1791351901792
# _TableStyle('Medium Grid 1 Accent 3') id: 1791352185888
# _TableStyle('Medium Grid 1 Accent 4') id: 1791351901792
# _TableStyle('Medium Grid 1 Accent 5') id: 1791352185888
# _TableStyle('Medium Grid 1 Accent 6') id: 1791351901792
# _TableStyle('Medium Grid 2') id: 1791352185888
# _TableStyle('Medium Grid 2 Accent 1') id: 1791351901792
# _TableStyle('Medium Grid 2 Accent 2') id: 1791352185888
# _TableStyle('Medium Grid 2 Accent 3') id: 1791351901792
# _TableStyle('Medium Grid 2 Accent 4') id: 1791352185888
# _TableStyle('Medium Grid 2 Accent 5') id: 1791351901792
# _TableStyle('Medium Grid 2 Accent 6') id: 1791352185888
# _TableStyle('Medium Grid 3') id: 1791351901792
# _TableStyle('Medium Grid 3 Accent 1') id: 1791352185888
# _TableStyle('Medium Grid 3 Accent 2') id: 1791351901792
# _TableStyle('Medium Grid 3 Accent 3') id: 1791352185888
# _TableStyle('Medium Grid 3 Accent 4') id: 1791351901792
# _TableStyle('Medium Grid 3 Accent 5') id: 1791352185888
# _TableStyle('Medium Grid 3 Accent 6') id: 1791351901792
# _TableStyle('Dark List') id: 1791352185888
# _TableStyle('Dark List Accent 1') id: 1791351901792
# _TableStyle('Dark List Accent 2') id: 1791352185888
# _TableStyle('Dark List Accent 3') id: 1791351901792
# _TableStyle('Dark List Accent 4') id: 1791352185888
# _TableStyle('Dark List Accent 5') id: 1791351901792
# _TableStyle('Dark List Accent 6') id: 1791352185888
# _TableStyle('Colorful Shading') id: 1791351901792
# _TableStyle('Colorful Shading Accent 1') id: 1791352185888
# _TableStyle('Colorful Shading Accent 2') id: 1791351901792
# _TableStyle('Colorful Shading Accent 3') id: 1791352185888
# _TableStyle('Colorful Shading Accent 4') id: 1791351901792
# _TableStyle('Colorful Shading Accent 5') id: 1791352185888
# _TableStyle('Colorful Shading Accent 6') id: 1791351901792
# _TableStyle('Colorful List') id: 1791352185888
# _TableStyle('Colorful List Accent 1') id: 1791351901792
# _TableStyle('Colorful List Accent 2') id: 1791352185888
# _TableStyle('Colorful List Accent 3') id: 1791351901792
# _TableStyle('Colorful List Accent 4') id: 1791352185888
# _TableStyle('Colorful List Accent 5') id: 1791351901792
# _TableStyle('Colorful List Accent 6') id: 1791352185888
# _TableStyle('Colorful Grid') id: 1791351901792
# _TableStyle('Colorful Grid Accent 1') id: 1791352185888
# _TableStyle('Colorful Grid Accent 2') id: 1791351901792
# _TableStyle('Colorful Grid Accent 3') id: 1791352185888
# _TableStyle('Colorful Grid Accent 4') id: 1791351901792
# _TableStyle('Colorful Grid Accent 5') id: 1791352185888
# _TableStyle('Colorful Grid Accent 6') id: 1791351901792

# %%
paragrafo_3 = documento.add_paragraph("Quantidade de produtos vendidos hoje: 4", "Heading 3")

# %% [markdown]
# ### Aproveitando um tampleta do word

# %%
template = Document('Template.docx')

# %%
for estilo in template.styles:
    print(estilo)

# %%
paragrafo_4 = template.add_paragraph("Quantidade de produtos", "EstiloNovo")
template.save('NovoTexto.docx')

# %% [markdown]
# ### Adcionar texto com edição dentro do texto

# %%
from docx import Document

#criando documento
documento = Document()

faturmaento = 1000

texto = f"""Paulo
O faturamento da empresa ontem foi de"""

resultado = f"""R${faturmaento}"""

texto_final = """Att."""

paragrafo = documento.add_paragraph(texto)

paragrafo.add_run(resultado).bold = True

paragrafo = documento.add_paragraph(texto_final)

documento.save("Texto.docx")

# %% [markdown]
# ### Controle de margem e seção

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

faturmaento = 1000

texto = f"""Paulo
O faturamento da empresa ontem foi de
{faturmaento}"""

paragrafo = documento.add_paragraph(texto)
paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save("Texto.docx")

# %% [markdown]
# ### Inserir imagens

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

faturmaento = 1000

texto = f"""Paulo
O faturamento da empresa ontem foi de
{faturmaento}"""

paragrafo = documento.add_paragraph()

imagem = documento.add_picture('eu.jpeg', width=Cm(8))

documento.save("Texto.docx")

# %% [markdown]
# ### Inserir Tabela

# %%
documento = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = documento.add_table(rows=1, cols=3, style='Colorful Grid Accent 3')
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc

documento.save("Texto.docx")

# %% [markdown]
# ### Adaptar um documento

# %%
from datetime import datetime

documento = Document('Contrato.docx')

nome = "Paulo"
item1 = "Seviço" 
item2 = "Apostila" 
item3 = "Treinamento" 

dicionario_valores = {
    'XXXX': nome,
    'YYYY': item1,
    'ZZZZ': item2,
    'WWWW': item3,
    'DD': str(datetime.now().day),
    'MM': str(datetime.now().month),
    'AAAA': str(datetime.now().year),
}

for paragrafo in documento.paragraphs:
    for codigo in dicionario_valores:
        if codigo in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(codigo, dicionario_valores[codigo])

documento.save("Contrato_Atualizado.docx")
